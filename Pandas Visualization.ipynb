# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',periods=10), columns=list('ABCD'))
print(df)
df.plot()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.984374  0.692001 -0.619758  0.684360
# 2000-01-02  1.957661  1.333149  1.509362 -0.187449
# 2000-01-03 -0.016659 -1.148821  1.632352 -0.214060
# 2000-01-04 -0.448867  0.427013  0.728837  1.949612
# 2000-01-05  2.511960  0.193138  0.821443  1.196894
# 2000-01-06  0.492062  0.459449 -0.570764 -0.091957
# 2000-01-07 -0.440703  0.928008  0.491718 -0.492988
# 2000-01-08  0.660942 -0.305132 -0.089830  1.517344
# 2000-01-09 -1.380720  0.219702 -1.102619  0.496833
# 2000-01-10  0.355788  0.811462 -0.531751  1.325734
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,2),index=pd.date_range('1/1/2000',periods=10), columns=list(['A','B']))
print(df)
df.plot()
# Out:
#                    A         B
# 2000-01-01 -0.185632  2.412685
# 2000-01-02 -0.493257 -0.586222
# 2000-01-03  0.870052  1.561711
# 2000-01-04  0.497657  1.151436
# 2000-01-05  1.740114  0.385186
# 2000-01-06  0.194547  0.267370
# 2000-01-07  0.071811  0.880445
# 2000-01-08  0.335530  0.032414
# 2000-01-09  0.214616 -0.356012
# 2000-01-10  0.716418 -0.360532
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
print(df)
df.plot.bar()
# Out:
#           A         B         C         D
# 0  0.427539  0.763295  0.712509  0.581613
# 1  0.890158  0.676660  0.150015  0.638953
# 2  0.942690  0.818601  0.309342  0.914868
# 3  0.728569  0.958029  0.672838  0.468416
# 4  0.469496  0.246915  0.958423  0.791281
# 5  0.626399  0.158495  0.868319  0.468931
# 6  0.713131  0.422839  0.783241  0.152781
# 7  0.262856  0.070140  0.674305  0.038447
# 8  0.140659  0.264022  0.914141  0.239207
# 9  0.182644  0.955105  0.969011  0.015668
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
colors=["red","black","white","green"]
print(df)
df.plot.bar(stacked=True,color=colors)
# Out:
#           a         b         c         d
# 0  0.247510  0.363707  0.443612  0.049872
# 1  0.419715  0.315914  0.855448  0.337762
# 2  0.602181  0.119478  0.024088  0.960525
# 3  0.201107  0.015406  0.331656  0.534674
# 4  0.590557  0.105761  0.035166  0.833911
# 5  0.521082  0.457264  0.461059  0.431748
# 6  0.490457  0.430958  0.760228  0.137259
# 7  0.818603  0.502564  0.785367  0.201930
# 8  0.973263  0.723407  0.903241  0.773398
# 9  0.604442  0.446236  0.315501  0.151938
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,2),columns=['a','b'])
colors=["red","black","white","green"]
print(df)
df.plot.barh(stacked=True,color=colors)
# Out:
#           a         b
# 0  0.680072  0.215479
# 1  0.914785  0.599796
# 2  0.102454  0.779436
# 3  0.956698  0.190991
# 4  0.694462  0.373328
# 5  0.960522  0.411684
# 6  0.047876  0.858007
# 7  0.725927  0.063846
# 8  0.915249  0.170944
# 9  0.790367  0.572728
# <AxesSubplot:>

# %%
import pandas  as pd
import numpy as np
df=pd.DataFrame(np.random.rand(5,2),columns=['a','b'])
print(df)
V=df.plot.hist()
V.set_facecolor("red")
# Out:
#           a         b
# 0  0.098165  0.989349
# 1  0.454229  0.374597
# 2  0.396984  0.736884
# 3  0.847891  0.228744
# 4  0.545840  0.913494

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.rand(1000)+1,'b':np.random.rand(1000)},columns=['a','b'])
print(df)
df.plot.hist(bins=200)
# Out:
#             a         b
# 0    1.732731  0.518860
# 1    1.154533  0.918490
# 2    1.989092  0.370794
# 3    1.367451  0.376440
# 4    1.444702  0.618685
# ..        ...       ...
# 995  1.439118  0.633988
# 996  1.491536  0.060086
# 997  1.427879  0.703234
# 998  1.844262  0.700036
# 999  1.027467  0.444774
#
# [1000 rows x 2 columns]
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.box()
# Out:
#           a         b         c         d
# 0  0.931692  0.122375  0.033952  0.184988
# 1  0.328425  0.161675  0.162780  0.192823
# 2  0.926664  0.889857  0.400954  0.991455
# 3  0.915708  0.556501  0.332680  0.037922
# 4  0.067625  0.871119  0.522254  0.919597
# 5  0.139278  0.180286  0.788713  0.387426
# 6  0.068732  0.413550  0.461352  0.737760
# 7  0.965381  0.539533  0.946513  0.909187
# 8  0.946320  0.273923  0.766922  0.706160
# 9  0.353712  0.405613  0.653267  0.003723
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
print(df)
df.plot.scatter(x='a',y='c')
# Out:
#            a         b         c         d
# 0   0.409131  0.379586  0.616648  0.331821
# 1   0.668807  0.107923  0.037521  0.736196
# 2   0.397651  0.392668  0.941757  0.637824
# 3   0.065159  0.236482  0.382783  0.636067
# 4   0.148532  0.727903  0.914926  0.190483
# 5   0.540094  0.173346  0.172193  0.659403
# 6   0.955036  0.724694  0.305301  0.168558
# 7   0.433468  0.104921  0.681265  0.684104
# 8   0.761297  0.568711  0.206224  0.809369
# 9   0.883696  0.358241  0.408661  0.221381
# 10  0.655987  0.962356  0.561676  0.560083
# 11  0.036613  0.269713  0.369245  0.463022
# 12  0.490526  0.426009  0.868989  0.478530
# 13  0.411643  0.875067  0.049124  0.328473
# 14  0.128255  0.675710  0.863983  0.512313
# 15  0.770723  0.036364  0.592185  0.530916
# 16  0.633952  0.777461  0.138285  0.727853
# 17  0.189924  0.569202  0.852181  0.904797
# 18  0.902866  0.458172  0.983536  0.165707
# 19  0.091905  0.733571  0.334754  0.092635
# 20  0.327068  0.688935  0.068057  0.061329
# 21  0.715645  0.441714  0.143155  0.386316
# 22  0.989818  0.499423  0.359773  0.854676
# 23  0.965045  0.252216  0.822828  0.872468
# 24  0.639509  0.855673  0.452795  0.708482
# 25  0.347230  0.383563  0.857881  0.011165
# 26  0.110422  0.818984  0.978547  0.197823
# 27  0.159517  0.803174  0.812046  0.951710
# 28  0.042471  0.215066  0.472825  0.562572
# 29  0.229721  0.924766  0.496435  0.925819
# 30  0.855549  0.860921  0.961783  0.966113
# 31  0.261094  0.013925  0.723993  0.891437
# 32  0.135278  0.035381  0.804822  0.700727
# 33  0.577777  0.539438  0.719030  0.661087
# 34  0.311708  0.691282  0.279525  0.513985
# 35  0.689969  0.677890  0.618935  0.898019
# 36  0.029842  0.010530  0.629277  0.001162
# 37  0.307907  0.046267  0.427210  0.877175
# 38  0.925888  0.526887  0.692109  0.031536
# 39  0.974864  0.688037  0.019252  0.731661
# 40  0.329775  0.054157  0.355616  0.138350
# 41  0.082584  0.810146  0.202649  0.739042
# 42  0.966843  0.444878  0.399363  0.852020
# 43  0.093629  0.088527  0.789333  0.173627
# 44  0.903297  0.047838  0.113307  0.588765
# 45  0.911657  0.942853  0.422864  0.413073
# 46  0.984119  0.506989  0.917960  0.210491
# 47  0.176492  0.208401  0.040280  0.732841
# 48  0.627200  0.867956  0.982668  0.394196
# 49  0.656279  0.003623  0.880716  0.593509
# <AxesSubplot:xlabel='a', ylabel='c'>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.area()
# Out:
#           a         b         c         d
# 0  0.704664  0.144946  0.998314  0.617619
# 1  0.127075  0.387516  0.761835  0.269069
# 2  0.966117  0.501176  0.396417  0.868948
# 3  0.835444  0.179452  0.417539  0.823288
# 4  0.684155  0.998257  0.893633  0.944264
# 5  0.780395  0.584359  0.133313  0.869668
# 6  0.741071  0.975466  0.451945  0.071673
# 7  0.607511  0.068501  0.498706  0.401233
# 8  0.460598  0.226664  0.320515  0.570483
# 9  0.131758  0.910226  0.580714  0.242800
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(3*np.random.rand(4),index=['a','b','c','d'],columns=['x'])
print(df)
df.plot.pie(subplots=True)
# Out:
#           x
# a  0.755230
# b  2.338684
# c  1.592488
# d  1.052327
# array([<AxesSubplot:ylabel='x'>], dtype=object)
